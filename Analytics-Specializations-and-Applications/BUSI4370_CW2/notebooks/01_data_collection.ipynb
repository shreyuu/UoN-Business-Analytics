# %%
import json
import time
import re
from datetime import datetime, timezone
from pathlib import Path
from getpass import getpass

import pandas as pd
from atproto import Client
from atproto_client.models.app.bsky.feed.search_posts import Params as SearchParams

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
RAW_DIR = PROJECT_ROOT / "data" / "raw"
RAW_DIR.mkdir(parents=True, exist_ok=True)
print(f"Saving raw data to: {RAW_DIR}")
# Out:
# Saving raw data to: /Users/shreyu/VSCODE/junk/UoN-Business-Analytics/Analytics-Specializations-and-Applications/BUSI4370_CW2/data/raw

# %%
# BSKY_HANDLE = input("Bluesky handle (e.g. yourname.bsky.social): ").strip()
# BSKY_APP_PASSWORD = getpass("Bluesky App Password (xxxx-xxxx-xxxx-xxxx): ")

BSKY_HANDLE = "shreyuu-dev.bsky.social"
BSKY_APP_PASSWORD = "osip-pbxt-xnfz-52kf"
BASE_URL = "https://bsky.social/xrpc"


client = Client(base_url=BASE_URL)
profile = client.login(BSKY_HANDLE, BSKY_APP_PASSWORD)
print(f"Logged in as: {profile.display_name} (@{profile.handle})")
# Out:
# Logged in as:  (@shreyuu-dev.bsky.social)

# %%
def extract_post_record(post) -> dict:
    """Flatten a Bluesky post object to a dict suitable for a pandas row."""
    record = post.record
    author = post.author
    return {
        "uri": post.uri,
        "cid": post.cid,
        "author_did": author.did,
        "author_handle": author.handle,
        "author_display_name": getattr(author, "display_name", None),
        "text": getattr(record, "text", ""),
        "created_at": getattr(record, "created_at", None),
        "indexed_at": getattr(post, "indexed_at", None),
        "langs": ",".join(getattr(record, "langs", []) or []),
        "like_count": getattr(post, "like_count", 0) or 0,
        "repost_count": getattr(post, "repost_count", 0) or 0,
        "reply_count": getattr(post, "reply_count", 0) or 0,
        "quote_count": getattr(post, "quote_count", 0) or 0,
        "is_reply": bool(getattr(record, "reply", None)),
        "embed_type": (
            type(post.embed).__name__ if getattr(post, "embed", None) else None
        ),
    }

# %%
def paginated_search(query, max_posts=1000, lang="en", sort="latest",
                     sleep_seconds=0.5, verbose=True):
    """Repeatedly call Bluesky's search_posts endpoint until max_posts retrieved
    or no more results are available."""
    posts = []
    cursor = None
    page = 0
    while len(posts) < max_posts:
        params = SearchParams(
            q=query,
            limit=min(100, max_posts - len(posts)),
            cursor=cursor,
            lang=lang,
            sort=sort,
        )
        try:
            response = client.app.bsky.feed.search_posts(params)
        except Exception as e:
            print(f"  [warn] search call failed on page {page}: {e}")
            break

        page_posts = response.posts
        if not page_posts:
            break

        for post in page_posts:
            try:
                posts.append(extract_post_record(post))
            except Exception as e:
                print(f"  [warn] could not extract a post: {e}")

        cursor = response.cursor
        page += 1
        if verbose:
            print(f"  page {page:>3}: total posts so far = {len(posts):>4}")
        if cursor is None:
            break
        time.sleep(sleep_seconds)
    return posts

# %%
def fetch_profiles_batch(dids, batch_size=25, sleep_seconds=0.5):
    """Resolve author DIDs to full profile objects (followers, follows, bio)."""
    profiles = []
    unique_dids = list(dict.fromkeys(dids))
    for i in range(0, len(unique_dids), batch_size):
        batch = unique_dids[i : i + batch_size]
        try:
            response = client.app.bsky.actor.get_profiles({"actors": batch})
        except Exception as e:
            print(f"  [warn] profile batch {i // batch_size} failed: {e}")
            continue

        for p in response.profiles:
            profiles.append({
                "did": p.did,
                "handle": p.handle,
                "display_name": getattr(p, "display_name", None),
                "description": getattr(p, "description", None),
                "followers_count": getattr(p, "followers_count", 0) or 0,
                "follows_count": getattr(p, "follows_count", 0) or 0,
                "posts_count": getattr(p, "posts_count", 0) or 0,
                "created_at": getattr(p, "created_at", None),
                "indexed_at": getattr(p, "indexed_at", None),
                "verified": getattr(p, "verification", None) is not None,
            })
        time.sleep(sleep_seconds)
    return profiles

# %%
# Query strategy for media-publication brands:
#   - Domain queries (wired.com, theverge.com) capture posts that share or
#     embed published articles. Highest-yield, lowest-ambiguity.
#   - Handle queries (@wired.com, @theverge.com) capture posts that mention
#     or interact with the brands' official Bluesky accounts.
#   - Compound queries (e.g. "the verge", "wired magazine") capture text
#     references that don't link directly to the publication.
#
# Note: "Wired" alone is a common English adjective so we avoid it as a
# standalone query. "Verge" alone is also problematic ("on the verge of...").
# Both are mitigated by relying on domain and handle signals as primary,
# with phrase-bound queries as secondary.

BRAND_QUERIES = {
    "wired": [
        # Domain — highest signal
        "wired.com",
        # Handle
        "@wired.com",
        # Phrase queries
        '"wired magazine"',
        '"on wired"',
        '"via wired"',
        # Topical compounds — capture article-referencing posts
        '"wired says"',
        '"wired reports"',
        '"wired story"',
        '"wired article"',
        '"wired piece"',
    ],
    "theverge": [
        # Domain — highest signal
        "theverge.com",
        # Handle
        "@theverge.com",
        # Phrase queries
        '"the verge"',
        # Topical compounds
        '"verge says"',
        '"verge reports"',
        '"verge story"',
        '"verge article"',
        '"verge review"',
        '"according to the verge"',
    ],
}

POSTS_PER_QUERY = 500
TARGET_PER_BRAND = 2500   # collect generously; cleaning will trim

# %%
def collect_brand_posts(brand, queries):
    """Run every query for a brand, deduplicate by URI, return as DataFrame."""
    print(f"\n=== Collecting posts for: {brand} ===")
    all_posts = []
    for q in queries:
        print(f"  Query: {q!r}")
        posts = paginated_search(query=q, max_posts=POSTS_PER_QUERY)
        for p in posts:
            p["query"] = q
        all_posts.extend(posts)
        print(f"   -> {len(posts)} posts retrieved for this query")

    df = pd.DataFrame(all_posts)
    if df.empty:
        return df

    before = len(df)
    df = df.drop_duplicates(subset="uri", keep="first").reset_index(drop=True)
    print(f"  Deduplication: {before} -> {len(df)} unique posts")

    if len(df) > TARGET_PER_BRAND:
        df = df.head(TARGET_PER_BRAND).reset_index(drop=True)

    df["brand"] = brand
    return df

# %%
wired_df = collect_brand_posts("wired", BRAND_QUERIES["wired"])
print(f"\nWired total: {len(wired_df)} unique posts, {wired_df['author_did'].nunique()} unique authors")
wired_df[["author_handle", "text", "like_count", "repost_count"]].head(5)
# Out:
# === Collecting posts for: wired ===
#   Query: 'wired.com'
#   [warn] search call failed on page 0: Response(success=False, status_code=502, content=XrpcError(error='InternalServerError', message='Upstream server responded with a 500 error'), headers={'x-powered-by': 'Express', 'access-control-allow-origin': '*', 'ratelimit-limit': '3000', 'ratelimit-reset': '1777492565', 'ratelimit-remaining': '2998', 'ratelimit-policy': '3000;w=300', 'cache-control': 'private', 'vary': 'Authorization, Accept-Encoding', 'content-type': 'application/json; charset=utf-8', 'content-length': '86', 'etag': 'W/"56-L+jRpk9/y0j/QRmuMywPl8zmsSc"', 'date': 'Wed, 29 Apr 2026 19:51:08 GMT', 'keep-alive': 'timeout=90', 'strict-transport-security': 'max-age=63072000'})
#    -> 0 posts retrieved for this query
#   Query: '@wired.com'
#   page   1: total posts so far =   31
#    -> 31 posts retrieved for this query
#   Query: '"wired magazine"'
#   [warn] search call failed on page 0:
#    -> 0 posts retrieved for this query
#   Query: '"on wired"'
#   page   1: total posts so far =    5
#    -> 5 posts retrieved for this query
#   Query: '"via wired"'
#   [warn] search call failed on page 0:
#    -> 0 posts retrieved for this query
#   Query: '"wired says"'
#   page   1: total posts so far =   96
#   page   2: total posts so far =  102
#    -> 102 posts retrieved for this query
#   Query: '"wired reports"'
#   page   1: total posts so far =   97
#   page   2: total posts so far =  192
#   page   3: total posts so far =  287
#   page   4: total posts so far =  334
#    -> 334 posts retrieved for this query
#   Query: '"wired story"'
#   page   1: total posts so far =   98
#   page   2: total posts so far =  196
#   page   3: total posts so far =  291
#   page   4: total posts so far =  387
#   page   5: total posts so far =  403
#    -> 403 posts retrieved for this query
#   Query: '"wired article"'
#   page   1: total posts so far =   99
#   page   2: total posts so far =  197
#   page   3: total posts so far =  296
#   page   4: total posts so far =  396
#   page   5: total posts so far =  492
#   page   6: total posts so far =  500
#    -> 500 posts retrieved for this query
#   Query: '"wired piece"'
#   page   1: total posts so far =   99
#   page   2: total posts so far =  195
#   page   3: total posts so far =  290
#   page   4: total posts so far =  387
#   page   5: total posts so far =  413
#    -> 413 posts retrieved for this query
#   Deduplication: 1788 -> 1776 unique posts
#
# Wired total: 1776 unique posts, 1465 unique authors
#                  author_handle  \
# 0    jacerealstory.bsky.social
# 1  curiouserth2-9b.bsky.social
# 2                nicweyand.com
# 3         chalseym.bsky.social
# 4       thiccreese.bsky.social
#
#                                                 text  like_count  repost_count
# 0  The #CIA #Covert Operation: Episode 2: The Ext...           0             0
# 1  #EpsteinClass \n@eff.org \n@wired.com \n@indiv...           0             0
# 2  @wired.com WHAT DO YOU MEAN THIS IS MY LAST FR...           0             0
# 3  AI Slop Is Making the Internet Fake-Happy\n#cs...           0             0
# 4  NEW: The DIY gadget is, in part, a rejection o...         122            28

# %%
def highlight_wired(val):
    """Visual sanity-check that retrieved posts are actually about Wired."""
    pattern = r'(wired\.com|@wired\.com|wired\s+(magazine|says|reports|story|article|piece))'
    return re.sub(pattern, r'<mark>\1</mark>', str(val), flags=re.IGNORECASE)

wired_df['text'].head(15).to_frame().style.format(highlight_wired)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8da8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8da8_level0_col0" class="col_heading level0 col0" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8da8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8da8_row0_col0" class="data row0 col0" >The #CIA #Covert Operation: Episode 2: The Extraction by #Marriage to a U.S. Citizen  open.substack.com/pub/jacereal...  <mark>@wired.com</mark> @theverge.com @techcrunch.com @platformer.news.web.brid.gy @garbageday.email @niemanlab.org @puck.news @semafor.com #transnationalrepression #USA</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8da8_row1_col0" class="data row1 col0" >#EpsteinClass
# @eff.org
# <mark>@wired.com</mark>
# @indivisible.org
# @teslatakedown.com
# @youranoncentral.bsky.social
# @votersoftomorrow.org</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d8da8_row2_col0" class="data row2 col0" ><mark>@wired.com</mark> WHAT DO YOU MEAN THIS IS MY LAST FREE ARTICLE I JUST GOT HERE I HAVEN'T BEEN TO YOUR SITE IN MONTHS</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d8da8_row3_col0" class="data row3 col0" >AI Slop Is Making the Internet Fake-Happy
# #csulbsoc | <mark>@wired.com</mark>
# -
# www.<mark>wired.com</mark>/story/ai-slo...</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d8da8_row4_col0" class="data row4 col0" >NEW: The DIY gadget is, in part, a rejection of our current moment, dominated by the predictable flatness of generative AI and minimalist, mass-produced devices.
#
# Check out my news feature about cyberdecks for <mark>@wired.com</mark>✨
#
# www.<mark>wired.com</mark>/story/cyberd...</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d8da8_row5_col0" class="data row5 col0" >JUST LAUNCHED: WIRED Greece. LOOK CLOSER. <mark>wired.com</mark>.gr
#
# 🇬🇷 🌎 ♥️ <mark>@wired.com</mark></td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d8da8_row6_col0" class="data row6 col0" >Watch "Biomedical Scientist @drandrealove.bsky.social
# Answers More Pseudoscience Questions' | Tech Support | <mark>@wired.com</mark> 😎 youtu.be/hfBJTpewWos</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d8da8_row7_col0" class="data row7 col0" >@thiswillhold.bsky.social
#
# www.tiktok.com/t/ZP8g7u8yq/
#
# At what point will Dems be ASHAMED ENOUGH TO HAVE TGE SPINE TO ADMIT; ASSASSINATIONS DONT HAVE DPs WITH ASSISTANTS GUIDING & BLOCKING THEM? @democrats.senate.gov @democrats.org @lastweektonight.com @reallyamerican.bsky.social <mark>@wired.com</mark></td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d8da8_row8_col0" class="data row8 col0" >@democrats.senate.gov LOVE THEIR #TeamSchumerGoals - and flags www.tiktok.com/t/ZP8gWEUck/
# #DemsDoNothing @indivisiblememphis.bsky.social @thetnholler.bsky.social @ncronline.bsky.social @christianitytoday.com @europeanjournalists.org <mark>@wired.com</mark> @wiredproductions.com @ipsc.bsky.social @ajiunit.com</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d8da8_row9_col0" class="data row9 col0" ><mark>@wired.com</mark> @mattburgess1.bsky.social @npr.org @govexec.bsky.social @washingtonpost.com</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d8da8_row10_col0" class="data row10 col0" >'The #Iran War Is Impacting the Environment in Unseen Ways
# From toxic smoke and oil spills to rising emissions, poisoned soil, and damaged ecosystems, war can reshape the #environment long after the fighting stops.'
#
# Via <mark>@wired.com</mark></td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d8da8_row11_col0" class="data row11 col0" ><mark>@wired.com</mark> hires editors from @businessinsider.com and @bloomberg.com: talkingbiznews.com/media-news/1...</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d8da8_row12_col0" class="data row12 col0" >The latest brain-computer interface could help people with severe depression.
#
# The FDA has approved a trial testing a blueberry-sized implant that delivers mild stimulation to boost the brain's central executive network.
#
# More at <mark>@wired.com</mark>:
# www.<mark>wired.com</mark>/story/a-brai...</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d8da8_row13_col0" class="data row13 col0" >Very doubtful because President Trump preferred incompetent loosers...
#
# <mark>@wired.com</mark>
# #Substack
# #whitehouse-47.bsky.social
# @lincolnproject.us
# #economist.com
# " Fox "</td>
#     </tr>
#     <tr>
#       <th id="T_d8da8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d8da8_row14_col0" class="data row14 col0" >www.<mark>wired.com</mark>/story/palant...
#
# h/t <mark>@wired.com</mark></td>
#     </tr>
#   </tbody>
# </table>

# %%
verge_df = collect_brand_posts("theverge", BRAND_QUERIES["theverge"])
print(f"\nThe Verge total: {len(verge_df)} unique posts, {verge_df['author_did'].nunique()} unique authors")
verge_df[["author_handle", "text", "like_count", "repost_count"]].head(5)
# Out:
# === Collecting posts for: theverge ===
#   Query: 'theverge.com'
#   page   1: total posts so far =  100
#   page   2: total posts so far =  199
#   page   3: total posts so far =  298
#   page   4: total posts so far =  396
#   page   5: total posts so far =  492
#   page   6: total posts so far =  498
#   page   7: total posts so far =  500
#    -> 500 posts retrieved for this query
#   Query: '@theverge.com'
#   page   1: total posts so far =   99
#   page   2: total posts so far =  198
#   page   3: total posts so far =  297
#   page   4: total posts so far =  392
#   page   5: total posts so far =  489
#   page   6: total posts so far =  500
#    -> 500 posts retrieved for this query
#   Query: '"the verge"'
#   page   1: total posts so far =   99
#   page   2: total posts so far =  198
#   page   3: total posts so far =  298
#   page   4: total posts so far =  396
#   page   5: total posts so far =  494
#   page   6: total posts so far =  500
#    -> 500 posts retrieved for this query
#   Query: '"verge says"'
#   page   1: total posts so far =   42
#    -> 42 posts retrieved for this query
#   Query: '"verge reports"'
#   page   1: total posts so far =   95
#   page   2: total posts so far =   98
#    -> 98 posts retrieved for this query
#   Query: '"verge story"'
#   page   1: total posts so far =   76
#    -> 76 posts retrieved for this query
#   Query: '"verge article"'
#   page   1: total posts so far =   95
#   page   2: total posts so far =  191
#   page   3: total posts so far =  289
#   page   4: total posts so far =  385
#   page   5: total posts so far =  481
#   page   6: total posts so far =  497
#   page   7: total posts so far =  500
#    -> 500 posts retrieved for this query
#   Query: '"verge review"'
#   page   1: total posts so far =   42
#    -> 42 posts retrieved for this query
#   Query: '"according to the verge"'
#   page   1: total posts so far =   81
#   page   2: total posts so far =   98
#    -> 98 posts retrieved for this query
#   Deduplication: 2356 -> 1946 unique posts
#
# The Verge total: 1946 unique posts, 1514 unique authors
#                 author_handle  \
# 0          kcurry.bsky.social
# 1   jacerealstory.bsky.social
# 2       idlesloth.bsky.social
# 3  forensicgarlic.bsky.social
# 4          iamydb.bsky.social
#
#                                                 text  like_count  repost_count
# 0  xbox email addresses coming for xbox employees...           0             0
# 1  The #CIA #Covert Operation: Episode 2: The Ext...           0             0
# 2  Mojang employees will also be given an mojangc...           0             0
# 3  I already know what the 'Brendan Carr is a dum...           0             0
# 4  @joncooper-us.bsky.social @andrewjweinstein.co...           0             1

# %%
def highlight_verge(val):
    pattern = r'(theverge\.com|@theverge\.com|the\s+verge|verge\s+(says|reports|story|article|review))'
    return re.sub(pattern, r'<mark>\1</mark>', str(val), flags=re.IGNORECASE)

verge_df['text'].head(15).to_frame().style.format(highlight_verge)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b804">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b804_level0_col0" class="col_heading level0 col0" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b804_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b804_row0_col0" class="data row0 col0" >xbox email addresses coming for xbox employees - because "we are xbox" now apparently. {https://<mark>theverge.com</mark>/rss/index.xml} https://www.<mark>theverge.com</mark>/report/920525/microsoft-xbox-email-address-change</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0b804_row1_col0" class="data row1 col0" >The #CIA #Covert Operation: Episode 2: The Extraction by #Marriage to a U.S. Citizen  open.substack.com/pub/jacereal...  @wired.com <mark>@theverge.com</mark> @techcrunch.com @platformer.news.web.brid.gy @garbageday.email @niemanlab.org @puck.news @semafor.com #transnationalrepression #USA</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0b804_row2_col0" class="data row2 col0" >Mojang employees will also be given an mojangcom email address, and both Xbox and Mojang employees will still retain their microsoftcom email aliases.
#
# The change is being made as part of “strengthening the Xbox identity inside and outside of Microsoft,”
#
# <mark>theverge.com</mark>/report/92052...</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0b804_row3_col0" class="data row3 col0" >I already know what the 'Brendan Carr is a dummy ' segment of the <mark>@theverge.com</mark> podcast is going to be about...</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0b804_row4_col0" class="data row4 col0" >@joncooper-us.bsky.social @andrewjweinstein.com @propublica.org <mark>@theverge.com</mark> @cookpolitical.com @urocklive1.bsky.social @bluestormcomin1.bsky.social @cwebbonline.com @teapainusa.bsky.social @meidastouch.com @georgetakei.bsky.social @gtconway.bsky.social @aclu.org @patrioticmillionaires.org</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0b804_row5_col0" class="data row5 col0" ><mark>@theverge.com</mark> do a blog on arena sideline tech: clocks, scoreboards, buzzers</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0b804_row6_col0" class="data row6 col0" >Is it time for America's favourite podcast within a podcast???? <mark>@theverge.com</mark></td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0b804_row7_col0" class="data row7 col0" >elon musk testifies in trial against openai co-founders. this is getting real. {<mark>theverge.com</mark>} https://www.<mark>theverge.com</mark>/ai-artificial-intelligence/917052/elon-musk-takes-stand-trial-openai-sam-altman</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0b804_row8_col0" class="data row8 col0" >Can't wait until this week's episode of "Brendan Carr is a Dummy"
#
# @reckless.bsky.social
# @davidpierce.xyz
# <mark>@theverge.com</mark></td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0b804_row9_col0" class="data row9 col0" >Great report from <mark>@theverge.com</mark> looking into the new era of cybersecurity, where even non-technical attackers can use AI to find the weaknesses in the apps and networks of organizations faster and at a scale never thought possible before.
# www.<mark>theverge.com</mark>/ai-artificia...</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0b804_row10_col0" class="data row10 col0" >#Mythos & the new #AI models got you scared? I shared some practical advice & optimism in this otherwise dire disaster prediction fest in my comments to @yaelwrites.com for <mark>@theverge.com</mark></td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0b804_row11_col0" class="data row11 col0" >should also tag @trailofbits.bsky.social and of course @mfortki.bsky.social and <mark>@theverge.com</mark>, it's early here 💕</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0b804_row12_col0" class="data row12 col0" >Google is Testing #AI Chatbot Search For YouTube (via <mark>@theverge.com</mark>) www.<mark>theverge.com</mark>/streaming/91... #LLMs #GenAI #videosearch</td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0b804_row13_col0" class="data row13 col0" >Google is Testing AI Chatbot Search For YouTube ~ <mark>theverge.com</mark>/streaming/91... #YouTube #AIChatbot via <mark>@theverge.com</mark></td>
#     </tr>
#     <tr>
#       <th id="T_0b804_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0b804_row14_col0" class="data row14 col0" >This makes me so happy that <mark>@theverge.com</mark> is embracing “The Year of Linux” on their website</td>
#     </tr>
#   </tbody>
# </table>

# %%
wired_path = RAW_DIR / "wired_posts_raw.csv"
verge_path = RAW_DIR / "theverge_posts_raw.csv"

wired_df.to_csv(wired_path, index=False)
verge_df.to_csv(verge_path, index=False)

print(f"Saved {len(wired_df)} Wired posts -> {wired_path}")
print(f"Saved {len(verge_df)} Verge posts -> {verge_path}")
# Out:
# Saved 1776 Wired posts -> /Users/shreyu/VSCODE/junk/UoN-Business-Analytics/Analytics-Specializations-and-Applications/BUSI4370_CW2/data/raw/wired_posts_raw.csv
# Saved 1946 Verge posts -> /Users/shreyu/VSCODE/junk/UoN-Business-Analytics/Analytics-Specializations-and-Applications/BUSI4370_CW2/data/raw/theverge_posts_raw.csv

# %%
print("Fetching profiles for Wired authors...")
wired_dids = wired_df["author_did"].dropna().unique().tolist()
wired_profiles = pd.DataFrame(fetch_profiles_batch(wired_dids))
print(f"  -> {len(wired_profiles)} profiles fetched")

print("\nFetching profiles for The Verge authors...")
verge_dids = verge_df["author_did"].dropna().unique().tolist()
verge_profiles = pd.DataFrame(fetch_profiles_batch(verge_dids))
print(f"  -> {len(verge_profiles)} profiles fetched")
# Out:
# Fetching profiles for Wired authors...
#   -> 1465 profiles fetched
#
# Fetching profiles for The Verge authors...
#   -> 1514 profiles fetched

# %%
wired_profiles_path = RAW_DIR / "wired_profiles_raw.csv"
verge_profiles_path = RAW_DIR / "theverge_profiles_raw.csv"

wired_profiles.to_csv(wired_profiles_path, index=False)
verge_profiles.to_csv(verge_profiles_path, index=False)

print(f"Saved {len(wired_profiles)} Wired profiles")
print(f"Saved {len(verge_profiles)} Verge profiles")
# Out:
# Saved 1465 Wired profiles
# Saved 1514 Verge profiles

# %%
def date_range(df):
    if df.empty or "created_at" not in df.columns:
        return ("n/a", "n/a")
    s = pd.to_datetime(df["created_at"], errors="coerce", utc=True)
    return (str(s.min()), str(s.max()))

metadata = {
    "collection_run_at": datetime.now(timezone.utc).isoformat(),
    "collected_by_handle": BSKY_HANDLE,
    "language_filter": "en",
    "sort_order": "latest",
    "geographic_scope": "global (Bluesky search does not expose location filtering)",
    "brand_pair_rationale": (
        "Wired vs The Verge selected as direct competitors in technology "
        "journalism with distinct editorial positioning (long-form/culture vs "
        "product-review/news-cycle). Brand pair was changed from an initial "
        "Hugging Face vs Replicate selection after pilot data showed that "
        "'replicate' as a common English verb produced unresolvable lexical "
        "collision under any reasonable precision/recall trade-off."
    ),
    "brands": {
        "wired": {
            "queries": BRAND_QUERIES["wired"],
            "n_posts": int(len(wired_df)),
            "n_unique_users": int(wired_df["author_did"].nunique()) if not wired_df.empty else 0,
            "date_range": date_range(wired_df),
            "n_profiles_fetched": int(len(wired_profiles)),
        },
        "theverge": {
            "queries": BRAND_QUERIES["theverge"],
            "n_posts": int(len(verge_df)),
            "n_unique_users": int(verge_df["author_did"].nunique()) if not verge_df.empty else 0,
            "date_range": date_range(verge_df),
            "n_profiles_fetched": int(len(verge_profiles)),
        },
    },
}

meta_path = RAW_DIR / "collection_metadata.json"
with open(meta_path, "w") as f:
    json.dump(metadata, f, indent=2)

print(json.dumps(metadata, indent=2))
# Out:
# {
#   "collection_run_at": "2026-04-29T19:54:22.440165+00:00",
#   "collected_by_handle": "shreyuu-dev.bsky.social",
#   "language_filter": "en",
#   "sort_order": "latest",
#   "geographic_scope": "global (Bluesky search does not expose location filtering)",
#   "brand_pair_rationale": "Wired vs The Verge selected as direct competitors in technology journalism with distinct editorial positioning (long-form/culture vs product-review/news-cycle). Brand pair was changed from an initial Hugging Face vs Replicate selection after pilot data showed that 'replicate' as a common English verb produced unresolvable lexical collision under any reasonable precision/recall trade-off.",
#   "brands": {
#     "wired": {
#       "queries": [
#         "wired.com",
#         "@wired.com",
#         "\"wired magazine\"",
#         "\"on wired\"",
#         "\"via wired\"",
#         "\"wired says\"",
#         "\"wired reports\"",
#         "\"wired story\"",
#         "\"wired article\"",
#         "\"wired piece\""
#       ],
#       "n_posts": 1776,
#       "n_unique_users": 1465,
#       "date_range": [
#         "2023-07-07 12:52:25.282000+00:00",
#         "2026-04-29 16:37:42.505000+00:00"
#       ],
#       "n_profiles_fetched": 1465
#     },
#     "theverge": {
#       "queries": [
#         "theverge.com",
#         "@theverge.com",
#         "\"the verge\"",
#         "\"verge says\"",
#         "\"verge reports\"",
#         "\"verge story\"",
#         "\"verge article\"",
#         "\"verge review\"",
#         "\"according to the verge\""
#       ],
#       "n_posts": 1946,
#       "n_unique_users": 1514,
#       "date_range": [
#         "2023-07-03 17:39:11.855000+00:00",
#         "2026-04-29 19:46:59.164000+00:00"
#       ],
#       "n_profiles_fetched": 1514
#     }
#   }
# }

# %%
def quick_summary(df, name):
    print(f"--- {name} ---")
    if df.empty:
        print(" (empty)")
        return
    print(f"  Total posts:     {len(df)}")
    print(f"  Unique authors:  {df['author_did'].nunique()}")
    print(f"  Date range:      {date_range(df)}")
    print(f"  Mean likes/post: {df['like_count'].mean():.2f}")
    print(f"  Mean reposts/post: {df['repost_count'].mean():.2f}")
    print(f"  Reply share:     {df['is_reply'].mean():.1%}")

quick_summary(wired_df, "Wired")
print()
quick_summary(verge_df, "The Verge")
# Out:
# --- Wired ---
#   Total posts:     1776
#   Unique authors:  1465
#   Date range:      ('2023-07-07 12:52:25.282000+00:00', '2026-04-29 16:37:42.505000+00:00')
#   Mean likes/post: 20.00
#   Mean reposts/post: 5.31
#   Reply share:     46.8%
#
# --- The Verge ---
#   Total posts:     1946
#   Unique authors:  1514
#   Date range:      ('2023-07-03 17:39:11.855000+00:00', '2026-04-29 19:46:59.164000+00:00')
#   Mean likes/post: 11.92
#   Mean reposts/post: 2.77
#   Reply share:     36.1%
