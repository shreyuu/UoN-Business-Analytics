# %%
import urllib.request
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("datas-loader") \
    .getOrCreate()

db_type = 'datas'
data_id = 74

exec(
    urllib.request.urlopen(
        "https://docs.google.com/uc?export=download&id=15U90KTe8YTtOTGCEJp3WyyESDU3QKUQk"
    ).read()
)
# Out:
# Exception in thread "main" java.lang.UnsupportedClassVersionError: org/apache/spark/launcher/Main has been compiled by a more recent version of the Java Runtime (class file version 61.0), this version of the Java Runtime only recognizes class file versions up to 52.0
# 	at java.lang.ClassLoader.defineClass1(Native Method)
# 	at java.lang.ClassLoader.defineClass(ClassLoader.java:756)
# 	at java.security.SecureClassLoader.defineClass(SecureClassLoader.java:142)
# 	at java.net.URLClassLoader.defineClass(URLClassLoader.java:473)
# 	at java.net.URLClassLoader.access$100(URLClassLoader.java:74)
# 	at java.net.URLClassLoader$1.run(URLClassLoader.java:369)
# 	at java.net.URLClassLoader$1.run(URLClassLoader.java:363)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.net.URLClassLoader.findClass(URLClassLoader.java:362)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:418)
# 	at sun.misc.Launcher$AppClassLoader.loadClass(Launcher.java:371)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:351)
# 	at sun.launcher.LauncherHelper.checkAndLoadMain(LauncherHelper.java:645)
# /Users/shreyu/VSCODE/junk/UoN-Business-Analytics/spark-env/lib/python3.14/site-packages/pyspark/bin/spark-class: line 97: CMD: bad array subscript
# head: illegal line count -- -1
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[1], line 6
#       1 import urllib.request
#       2 from pyspark.sql import SparkSession
#       4 spark = SparkSession.builder \
#       5     .appName("datas-loader") \
# ----> 6     .getOrCreate()
#       8 db_type = 'datas'
#       9 data_id = 74
#
# File ~/VSCODE/junk/UoN-Business-Analytics/spark-env/lib/python3.14/site-packages/pyspark/sql/session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File ~/VSCODE/junk/UoN-Business-Analytics/spark-env/lib/python3.14/site-packages/pyspark/core/context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File ~/VSCODE/junk/UoN-Business-Analytics/spark-env/lib/python3.14/site-packages/pyspark/core/context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File ~/VSCODE/junk/UoN-Business-Analytics/spark-env/lib/python3.14/site-packages/pyspark/core/context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File ~/VSCODE/junk/UoN-Business-Analytics/spark-env/lib/python3.14/site-packages/pyspark/java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.
